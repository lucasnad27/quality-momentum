# %%
import arrow
import pandas as pd
import pyfolio as pf
import numpy as np

import gzip
import math
import sys

sys.path.append('../../src')
sys.path.append('./src')

import quality_momentum as qm

import warnings
from matplotlib.cbook import MatplotlibDeprecationWarning

warnings.filterwarnings("ignore", category=MatplotlibDeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
start_date = arrow.get('1992-09-01')
end_date = arrow.get('2021-08-02')

# %%
portfolio = qm.portfolio.Portfolio(
    start_date=start_date, 
    end_date=end_date, 
    capital_allocation=100000.0,
    weighting=qm.portfolio.WeightType.equal_weighted,
    s3_bucket='prod-stock-universe')
portfolio.run()
# Out:
# Purchasing initial shares. day_0=<Arrow [1992-09-01T00:00:00+00:00]>
# Rebalancing portfolio...1992-11-30
# Rebalancing portfolio...1993-02-26
# Rebalancing portfolio...1993-05-28
# Rebalancing portfolio...1993-08-31
# Rebalancing portfolio...1993-11-30
# Rebalancing portfolio...1994-02-28
# Rebalancing portfolio...1994-05-31
# Rebalancing portfolio...1994-08-31
# Rebalancing portfolio...1994-11-30
# Rebalancing portfolio...1995-02-28
# Rebalancing portfolio...1995-05-31
# Rebalancing portfolio...1995-08-31
# Rebalancing portfolio...1995-11-30
# Rebalancing portfolio...1996-02-29
# Rebalancing portfolio...1996-05-31
# Rebalancing portfolio...1996-08-30
# Rebalancing portfolio...1996-11-29
# Rebalancing portfolio...1997-02-28
# Rebalancing portfolio...1997-05-30
# Rebalancing portfolio...1997-08-29
# Rebalancing portfolio...1997-11-28
# Rebalancing portfolio...1998-02-27
# Rebalancing portfolio...1998-05-29
# Rebalancing portfolio...1998-08-31
# Rebalancing portfolio...1998-11-30
# Rebalancing portfolio...1999-02-26
# Rebalancing portfolio...1999-05-28
# Rebalancing portfolio...1999-08-31
# Rebalancing portfolio...1999-11-30
# Rebalancing portfolio...2000-02-29
# Rebalancing portfolio...2000-05-31
# Rebalancing portfolio...2000-08-31
# Rebalancing portfolio...2000-11-30
# Rebalancing portfolio...2001-02-28
# Rebalancing portfolio...2001-05-31
# Rebalancing portfolio...2001-08-31
# Rebalancing portfolio...2001-11-30
# Rebalancing portfolio...2002-02-28
# Rebalancing portfolio...2002-05-31
# Rebalancing portfolio...2002-08-30
# Rebalancing portfolio...2002-11-29
# Rebalancing portfolio...2003-02-28
# Rebalancing portfolio...2003-05-30
# Rebalancing portfolio...2003-08-29
# Rebalancing portfolio...2003-11-28
# Rebalancing portfolio...2004-02-27
# Rebalancing portfolio...2004-05-28
# Rebalancing portfolio...2004-08-31
# Rebalancing portfolio...2004-11-30
# Rebalancing portfolio...2005-02-28
# Rebalancing portfolio...2005-05-31
# Rebalancing portfolio...2005-08-31
# Rebalancing portfolio...2005-11-30
# Rebalancing portfolio...2006-02-28
# Rebalancing portfolio...2006-05-31
# Rebalancing portfolio...2006-08-31
td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>61.67</td>
#       <td>2015-06-08</td>
#       <td>2018-12-24</td>
#       <td>2020-08-03</td>
#       <td>1346</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>52.95</td>
#       <td>2021-02-09</td>
#       <td>2021-07-19</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>35.87</td>
#       <td>2006-02-21</td>
#       <td>2006-10-03</td>
#       <td>2008-06-18</td>
#       <td>607</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Lehman</th>
#       <td>-0.76%</td>
#       <td>-7.86%</td>
#       <td>6.76%</td>
#     </tr>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>0.32%</td>
#       <td>-1.72%</td>
#       <td>4.20%</td>
#     </tr>
#     <tr>
#       <th>Flash Crash</th>
#       <td>-1.34%</td>
#       <td>-4.80%</td>
#       <td>6.25%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.02%</td>
#       <td>-3.16%</td>
#       <td>3.34%</td>
#     </tr>
#     <tr>
#       <th>GFC Crash</th>
#       <td>-0.14%</td>
#       <td>-12.70%</td>
#       <td>11.98%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SCOA</th>
#       <td>26.22%</td>
#     </tr>
#     <tr>
#       <th>GMNI</th>
#       <td>24.93%</td>
#     </tr>
#     <tr>
#       <th>SYN</th>
#       <td>20.68%</td>
#     </tr>
#     <tr>
#       <th>ECPG</th>
#       <td>19.24%</td>
#     </tr>
#     <tr>
#       <th>ZTNO</th>
#       <td>19.10%</td>
#     </tr>
#     <tr>
#       <th>YRIV</th>
#       <td>18.34%</td>
#     </tr>
#     <tr>
#       <th>OIBR-C</th>
#       <td>18.11%</td>
#     </tr>
#     <tr>
#       <th>SPCB</th>
#       <td>18.03%</td>
#     </tr>
#     <tr>
#       <th>ELCO</th>
#       <td>17.94%</td>
#     </tr>
#     <tr>
#       <th>KAVL</th>
#       <td>17.47%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>SCOA</th>
#       <td>26.22%</td>
#     </tr>
#     <tr>
#       <th>GMNI</th>
#       <td>24.93%</td>
#     </tr>
#     <tr>
#       <th>SYN</th>
#       <td>20.68%</td>
#     </tr>
#     <tr>
#       <th>ECPG</th>
#       <td>19.24%</td>
#     </tr>
#     <tr>
#       <th>ZTNO</th>
#       <td>19.10%</td>
#     </tr>
#     <tr>
#       <th>YRIV</th>
#       <td>18.34%</td>
#     </tr>
#     <tr>
#       <th>OIBR-C</th>
#       <td>18.11%</td>
#     </tr>
#     <tr>
#       <th>SPCB</th>
#       <td>18.03%</td>
#     </tr>
#     <tr>
#       <th>ELCO</th>
#       <td>17.94%</td>
#     </tr>
#     <tr>
#       <th>KAVL</th>
#       <td>17.47%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Instructions to export to pdf
#
# PDF is the preferred method of distribution for our results. Here's a [good article](https://towardsdatascience.com/how-to-convert-jupyter-notebooks-into-pdf-5accaef3758) describing the various methods for exporting. I've distilled it down to this command...
#
# `jupyter nbconvert --to pdf ./notebooks/backtests/percentile-40th.ipynb`
#
# You'll need to install appropriate dependencies for this to work. Namely, latex.
